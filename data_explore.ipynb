# %%
import pandas as pd

# %%
df = pd.read_csv('data/sf-loan-performance-data-sample.csv', sep='|')
balance_code_numer = 44
liczba_not_null =df.iloc[:, balance_code_numer].notna().sum()
print(f'Liczba wartości nie-null w kolumnie {df.columns[balance_code_numer]}: {liczba_not_null}')
# Out:
# Liczba wartości nie-null w kolumnie Unnamed: 44: 5
